# %%
for i in range(3):
  for j in range(4):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 1 0
# 1 1
# 1 2
# 1 3
# 2 0
# 2 1
# 2 2
# 2 3

# %%
for i in range(2):
  for j in range(5):
    print("i=",i,"j=")
    print(i,j)
# Out:
# i= 0 j=
# 0 0
# i= 0 j=
# 0 1
# i= 0 j=
# 0 2
# i= 0 j=
# 0 3
# i= 0 j=
# 0 4
# i= 1 j=
# 1 0
# i= 1 j=
# 1 1
# i= 1 j=
# 1 2
# i= 1 j=
# 1 3
# i= 1 j=
# 1 4

# %%
rows=int(input("enter rows:"))
cols=int(input("enter cols:"))
for i in range(rows):
  for j in range(cols):
    print("#",end="")
  print()
# Out:
# enter rows:5
# enter cols:6
# ######
# ######
# ######
# ######
# ######

# %%
for row in range(8):
  for col in range(8):
     print("%",end="")
print()
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
